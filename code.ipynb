# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\ujwal\\Downloads\\archive (11)\\Medicalpremium.csv")

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %%
df.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                               Age  Diabetes  BloodPressureProblems  \
# Age                      1.000000  0.210908               0.244888
# Diabetes                 0.210908  1.000000               0.127727
# BloodPressureProblems    0.244888  0.127727               1.000000
# AnyTransplants          -0.008549 -0.036652              -0.024538
# AnyChronicDiseases       0.051072 -0.089428               0.045424
# Height                   0.039879 -0.003783              -0.037926
# Weight                  -0.018590 -0.024563              -0.061016
# KnownAllergies          -0.024416 -0.080102              -0.011550
# HistoryOfCancerInFamily -0.027623 -0.055527               0.048239
# NumberOfMajorSurgeries   0.429181  0.122722               0.251568
# PremiumPrice             0.697540  0.076209               0.167097
#
#                          AnyTransplants  AnyChronicDiseases    Height  \
# Age                           -0.008549            0.051072  0.039879
# ...

# %%
""" data visualization"""
plt.scatter(df["Age"],df["Weight"],color='r')
plt.xlabel("Age")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
# Violin Plot: Age vs Diabetes
plt.figure(figsize=(12, 6))

# KDE plot for the density of age for both diabetes categories
sns.kdeplot(data=df, x="Age", hue="Diabetes", common_norm=False, fill=True, palette="coolwarm", linewidth=2)

# Strip plot to show individual points
sns.stripplot(data=df, x="Diabetes", y="Age", jitter=True, hue="Diabetes", dodge=True, marker="o", palette="coolwarm", alpha=0.6)

plt.xlabel("Diabetes (0 = No, 1 = Yes)")
plt.ylabel("Age")
plt.title("Age Distribution vs Diabetes (Density + Points)")
plt.legend(title="Diabetes", labels=["No", "Yes"])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
sns.histplot(df["PremiumPrice"], bins=30, kde=True, ax=axes[0, 0], color='blue')
axes[0, 0].set_title("Distribution of Premium Price")
sns.boxplot(y=df["PremiumPrice"], ax=axes[0, 1], color='orange')
axes[0, 1].set_title("Boxplot of Premium Price")
sns.scatterplot(x=df["Age"], y=df["PremiumPrice"], ax=axes[1, 0], color='green')
axes[1, 0].set_title("Age vs Premium Price")
sns.scatterplot(x=df["Weight"], y=df["PremiumPrice"], ax=axes[1, 1], color='red')
axes[1, 1].set_title("Weight vs Premium Price")
plt.tight_layout()
plt.show()
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries
# 0                       0
# 1                       0
# 2                       1
# 3                       2
# ...

# %%
y.head()
# Out:
# 0    25000
# 1    29000
# 2    23000
# 3    28000
# 4    23000
# Name: PremiumPrice, dtype: int64

# %%
""" TRAIN, TEST , SPLIT"""
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
sns.regplot(x=x["Age"], y=y)
# Out:
# <Axes: xlabel='Age', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["Diabetes"], y=y)
# Out:
# <Axes: xlabel='Diabetes', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["BloodPressureProblems"], y=y)
# Out:
# <Axes: xlabel='BloodPressureProblems', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["AnyTransplants"], y=y)
# Out:
# <Axes: xlabel='AnyTransplants', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["AnyChronicDiseases"], y=y)
# Out:
# <Axes: xlabel='AnyChronicDiseases', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["Height"], y=y)
# Out:
# <Axes: xlabel='Height', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["Weight"], y=y)
# Out:
# <Axes: xlabel='Weight', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["KnownAllergies"], y=y)
# Out:
# <Axes: xlabel='KnownAllergies', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["HistoryOfCancerInFamily"], y=y)
# Out:
# <Axes: xlabel='HistoryOfCancerInFamily', ylabel='PremiumPrice'>

# %%
sns.regplot(x=x["NumberOfMajorSurgeries"], y=y)
# Out:
# <Axes: xlabel='NumberOfMajorSurgeries', ylabel='PremiumPrice'>

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.02662995, -0.85479773, -0.91559186, ..., -0.53614965,
#         -0.35085653,  0.4474222 ],
#        [-0.54586548,  1.1698674 , -0.91559186, ..., -0.53614965,
#         -0.35085653, -0.88046938],
#        [-0.90367512,  1.1698674 , -0.91559186, ..., -0.53614965,
#         -0.35085653, -0.88046938],
#        ...,
#        [ 1.38630658,  1.1698674 , -0.91559186, ..., -0.53614965,
#         -0.35085653,  3.10320536],
#        [-0.33117969,  1.1698674 , -0.91559186, ...,  1.8651509 ,
#          2.85016785,  0.4474222 ],
#        [ 1.24318272,  1.1698674 ,  1.0921897 , ..., -0.53614965,
#          2.85016785,  0.4474222 ]])

# %%
X_test
# Out:
# array([[ 0.56865171, -0.83871823, -1.01222041, ...,  2.06284249,
#          2.46112634,  0.43466999],
#        [-0.22285787, -0.83871823, -1.01222041, ...,  2.06284249,
#          2.46112634,  0.43466999],
#        [ 1.64798294,  1.19229553,  0.98792712, ..., -0.48476799,
#         -0.40631803, -0.9243615 ],
#        ...,
#        [-0.22285787,  1.19229553,  0.98792712, ..., -0.48476799,
#         -0.40631803, -0.9243615 ],
#        [-1.3021891 ,  1.19229553, -1.01222041, ..., -0.48476799,
#         -0.40631803,  0.43466999],
#        [ 0.92842878, -0.83871823, -1.01222041, ..., -0.48476799,
#         -0.40631803, -0.9243615 ]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Perform Cross-Validation with multiprocessing (all CPU cores)
cv = 10  # Change to 5 or 10 for better speed-accuracy balance
mse_scores = cross_val_score(regression, X_train, y_train, scoring="neg_mean_squared_error", cv=cv, n_jobs=-1)

# Convert Negative MSE to RMSE
rmse_scores = np.sqrt(-mse_scores)

# Mean & Standard Deviation of RMSE
print(f"Cross-Validation RMSE: {rmse_scores.mean():.4f} ± {rmse_scores.std():.4f}")

# Get cross-validation predictions
y_pred_cv = cross_val_predict(regression, X_train, y_train, cv=cv, n_jobs=-1)

# Evaluate using R2 Score
r2 = r2_score(y_train, y_pred_cv)
print(f"Cross-Validation R2 Score: {r2:.4f}")
# Out:
# Cross-Validation RMSE: 3825.6621 ± 596.9602
# Cross-Validation R2 Score: 0.5982

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# Train the model on full training data
regression.fit(X_train, y_train)

# Make predictions on the test set
y_pred = regression.predict(X_test)

# Evaluate Performance
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Test RMSE: {rmse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test R² Score: {r2:.4f}")
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.6, color="blue")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red", linestyle="--")  # Perfect Fit Line
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()
# Out:
# Test RMSE: 3760.5192
# Test MAE: 2705.6151
# Test R² Score: 0.6758

# %%
""" average of cross validation"""
cv_mean = np.mean(rmse_scores)
print("Mean RMSE from Cross-Validation:", cv_mean)
# Out:
# Mean RMSE from Cross-Validation: 3825.6620718564445

# %%
""" predection """
y_pred=regression.predict(X_test)

# %%
print(y_pred)
# Out:
# [27820.34964237 26032.62123737 31505.13122973 19761.00596653
#  25859.49399717 25548.20235439 23819.39491788 22096.98144629
#  25952.25785535 29807.74145968 22374.39271699 27560.69335741
#  16990.91351027 17480.43400954 29965.21021991 25643.65311804
#  28526.58978166 31283.2659256  28410.92930415 20684.06459556
#  33583.94082818 15842.20543168 23274.12743121 28173.30732079
#  30718.85470995 27840.91014819 24742.7872519  25556.22649802
#  17112.29072987 26009.16841383 21456.23076493 24197.86168743
#  19033.04095737 21990.99666618 15531.68325598 34567.3024689
#  22306.38727946 20996.55545789 17757.67543822 25780.00709578
#  26405.83017622 23898.69114035 22223.80055957 19789.83282414
#  17235.13236227 25188.11234822 25177.21324565 24857.66761737
#  15071.47920361 26002.1999131  23538.05285612 18366.39835227
#  25872.68144227 18608.07918123 27003.87436373 22149.67405764
#  22044.8580962  23641.61777729 26961.98951131 27125.09012889
# ...

# %%
""" performance metrics"""
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 14141504.591426339
# 2705.6151423354627
# 3760.519191737537

# %%
import pandas as pd

y_pred_df = pd.DataFrame(y_pred, columns=["Predicted"])
print(y_pred_df.head())  # Show first 5 predictions
# Out:
#       Predicted
# 0  27820.349642
# 1  26032.621237
# 2  31505.131230
# 3  19761.005967
# 4  25859.493997

# %%
comparison = pd.DataFrame({"Actual": y_test.values, "Predicted": y_pred})
print(comparison.head(10))  # Show first 10 comparisons
# Out:
#    Actual     Predicted
# 0   31000  27820.349642
# 1   31000  26032.621237
# 2   29000  31505.131230
# 3   15000  19761.005967
# 4   23000  25859.493997
# 5   29000  25548.202354
# 6   25000  23819.394918
# 7   23000  22096.981446
# 8   28000  25952.257855
# 9   28000  29807.741460

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score) 
print(1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
# Out:
# 0.6757712622227297
# 0.6620327563847097

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 613     3179.650358
# 451     4967.378763
# 731    -2505.131230
# 436    -4761.005967
# 275    -2859.493997
#            ...
# 597      702.876830
# 204    16254.258982
# 514      674.785719
# 628    -2325.803283
# 945     1448.239934
# Name: PremiumPrice, Length: 247, dtype: float64

# %%
sns.displot(residuals,kind='kde')

# %%
plt.scatter(y_pred,residuals)

# %%
import statsmodels.api as sm
model=sm.OLS(y_train,X_train).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           PremiumPrice   R-squared (uncentered):                   0.037
# Model:                            OLS   Adj. R-squared (uncentered):              0.024
# Method:                 Least Squares   F-statistic:                              2.822
# Date:                Wed, 29 Jan 2025   Prob (F-statistic):                     0.00192
# Time:                        22:08:55   Log-Likelihood:                         -8515.7
# No. Observations:                 739   AIC:                                  1.705e+04
# Df Residuals:                     729   BIC:                                  1.710e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
print(regression.coef_)
# Out:
# [4574.39976315 -150.74297126   13.06250572 1576.98752223 1002.59986703
#   -18.85503125  946.51281758   65.03042908  579.14221878 -477.50044594]

# %%
""" save model"""
import joblib
joblib.dump(regression, "regression_model.pkl")
print("Model saved successfully!")
# Out:
# Model saved successfully!
